# %%
pwd
# Out:
# 'C:\\Users\\ols'

# %%
import numpy as np 
import pandas as pd 
import os

# %%
activity = pd.read_csv('FitBit data.csv')

# %%
activity.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
# 3                 4.95                      0.0                 39
# 4                 4.61                      0.0                 28
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                   12                   205               804      1819
# 1                   17                   274               588      2154
# 2                    5                   268               605      1944
# 3                   20                   224              1080      1932
# 4                   28                   243               763      1886

# %%
activity.tail()
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
# 456                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938

# %%
activity.shape
# Out:
# (457, 15)

# %%
activity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        457 non-null    int64
#  1   ActivityDate              457 non-null    object
#  2   TotalSteps                457 non-null    int64
#  3   TotalDistance             457 non-null    float64
#  4   TrackerDistance           457 non-null    float64
#  5   LoggedActivitiesDistance  457 non-null    float64
#  6   VeryActiveDistance        457 non-null    float64
#  7   ModeratelyActiveDistance  457 non-null    float64
#  8   LightActiveDistance       457 non-null    float64
#  9   SedentaryActiveDistance   457 non-null    float64
#  10  VeryActiveMinutes         457 non-null    int64
#  11  FairlyActiveMinutes       457 non-null    int64
#  12  LightlyActiveMinutes      457 non-null    int64
#  13  SedentaryMinutes          457 non-null    int64
#  14  Calories                  457 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 53.7+ KB

# %%
activity.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')

# %%
import pandas_profiling

# %%
activity.shape
# Out:
# (457, 15)

# %%
activity.isnull().sum()
# Out:
# Id                          0
# ActivityDate                0
# TotalSteps                  0
# TotalDistance               0
# TrackerDistance             0
# LoggedActivitiesDistance    0
# VeryActiveDistance          0
# ModeratelyActiveDistance    0
# LightActiveDistance         0
# SedentaryActiveDistance     0
# VeryActiveMinutes           0
# FairlyActiveMinutes         0
# LightlyActiveMinutes        0
# SedentaryMinutes            0
# Calories                    0
# dtype: int64

# %%
activity.head(10)
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
# 5  1503960366    3/30/2016       10970           7.16             7.16
# 6  1503960366    3/31/2016       12256           7.86             7.86
# 7  1503960366     4/1/2016       12262           7.87             7.87
# 8  1503960366     4/2/2016       11248           7.25             7.25
# 9  1503960366     4/3/2016       10016           6.37             6.37
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
# 5                       0.0                2.36                      0.51
# 6                       0.0                2.29                      0.49
# 7                       0.0                3.32                      0.83
# 8                       0.0                3.00                      0.45
# 9                       0.0                0.91                      1.28
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
# 3                 4.95                      0.0                 39
# 4                 4.61                      0.0                 28
# 5                 4.29                      0.0                 30
# 6                 5.04                      0.0                 33
# 7                 3.64                      0.0                 47
# 8                 3.74                      0.0                 40
# 9                 4.18                      0.0                 15
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                   12                   205               804      1819
# 1                   17                   274               588      2154
# 2                    5                   268               605      1944
# 3                   20                   224              1080      1932
# 4                   28                   243               763      1886
# 5                   13                   223              1174      1820
# 6                   12                   239               820      1889
# 7                   21                   200               866      1868
# 8                   11                   244               636      1843
# 9                   30                   314               655      1850

# %%
activity1=activity.copy()

# %%
activity1
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   4.07                     0.00                 33
# 1                   3.91                     0.00                 89
# 2                   3.71                     0.00                 56
# 3                   4.95                     0.00                 39
# 4                   4.61                     0.00                 28
# ..                   ...                      ...                ...
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
# 456                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
# [457 rows x 15 columns]

# %%
activity1['ActivityDate'].unique()
# Out:
# array(['3/25/2016', '3/26/2016', '3/27/2016', '3/28/2016', '3/29/2016',
#        '3/30/2016', '3/31/2016', '4/1/2016', '4/2/2016', '4/3/2016',
#        '4/4/2016', '4/5/2016', '4/6/2016', '4/7/2016', '4/8/2016',
#        '4/9/2016', '4/10/2016', '4/11/2016', '4/12/2016', '3/12/2016',
#        '3/13/2016', '3/14/2016', '3/15/2016', '3/16/2016', '3/17/2016',
#        '3/18/2016', '3/19/2016', '3/20/2016', '3/21/2016', '3/22/2016',
#        '3/23/2016', '3/24/2016'], dtype=object)

# %%
activity1['ActivityDate'].head(10)
# Out:
# 0    3/25/2016
# 1    3/26/2016
# 2    3/27/2016
# 3    3/28/2016
# 4    3/29/2016
# 5    3/30/2016
# 6    3/31/2016
# 7     4/1/2016
# 8     4/2/2016
# 9     4/3/2016
# Name: ActivityDate, dtype: object

# %%
activity1["year"]=pd.DatetimeIndex(activity1["ActivityDate"]).year

# %%
activity1.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
# 3                 4.95                      0.0                 39
# 4                 4.61                      0.0                 28
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  year
# 0                   12                   205               804      1819  2016
# 1                   17                   274               588      2154  2016
# 2                    5                   268               605      1944  2016
# 3                   20                   224              1080      1932  2016
# 4                   28                   243               763      1886  2016

# %%
activity1["month"]=pd.DatetimeIndex(activity1["ActivityDate"]).month
activity1["date"]=pd.DatetimeIndex(activity1["ActivityDate"]).day

# %%
activity1.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
# 3                 4.95                      0.0                 39
# 4                 4.61                      0.0                 28
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                   12                   205               804      1819
# 1                   17                   274               588      2154
# 2                    5                   268               605      1944
# 3                   20                   224              1080      1932
# 4                   28                   243               763      1886
#
#    year  month  date
# 0  2016      3    25
# 1  2016      3    26
# 2  2016      3    27
# 3  2016      3    28
# 4  2016      3    29

# %%
activity1=activity1.drop(['TrackerDistance'],axis=1)

# %%
activity1.head(200)
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  \
# 0    1503960366    3/25/2016       11004           7.11
# 1    1503960366    3/26/2016       17609          11.55
# 2    1503960366    3/27/2016       12736           8.53
# 3    1503960366    3/28/2016       13231           8.93
# 4    1503960366    3/29/2016       12041           7.85
# ..          ...          ...         ...            ...
# 195  4020332650    4/11/2016        2993           2.15
# 196  4020332650    4/12/2016           8           0.01
# 197  4057192912    3/12/2016           0           0.00
# 198  4057192912    3/13/2016           0           0.00
# 199  4057192912    3/14/2016        8433           6.23
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 195                       0.0                0.00                      0.00
# 196                       0.0                0.00                      0.00
# 197                       0.0                0.00                      0.00
# 198                       0.0                0.00                      0.00
# 199                       0.0                2.45                      0.33
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   4.07                      0.0                 33
# 1                   3.91                      0.0                 89
# 2                   3.71                      0.0                 56
# 3                   4.95                      0.0                 39
# 4                   4.61                      0.0                 28
# ..                   ...                      ...                ...
# 195                 2.09                      0.0                  0
# 196                 0.01                      0.0                  0
# 197                 0.00                      0.0                  0
# 198                 0.00                      0.0                  0
# 199                 3.44                      0.0                 30
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 195                    0                   114               888      2507
# 196                    0                     1               321       446
# 197                    0                     0              1440      1777
# 198                    0                     0              1440      1777
# 199                    7                   135              1268      2453
#
#      year  month  date
# 0    2016      3    25
# 1    2016      3    26
# 2    2016      3    27
# 3    2016      3    28
# 4    2016      3    29
# ..    ...    ...   ...
# 195  2016      4    11
# 196  2016      4    12
# 197  2016      3    12
# 198  2016      3    13
# 199  2016      3    14
#
# [200 rows x 17 columns]

# %%
activity1.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  LoggedActivitiesDistance  \
# count  4.570000e+02    457.000000     457.000000                457.000000
# mean   4.628595e+09   6546.562363       4.663523                  0.179427
# std    2.293781e+09   5398.493064       4.082072                  0.849232
# min    1.503960e+09      0.000000       0.000000                  0.000000
# 25%    2.347168e+09   1988.000000       1.410000                  0.000000
# 50%    4.057193e+09   5986.000000       4.090000                  0.000000
# 75%    6.391747e+09  10198.000000       7.160000                  0.000000
# max    8.877689e+09  28497.000000      27.530001                  6.727057
#
#        VeryActiveDistance  ModeratelyActiveDistance  LightActiveDistance  \
# count          457.000000                457.000000           457.000000
# mean             1.180897                  0.478643             2.890197
# std              2.487159                  0.830995             2.237523
# min              0.000000                  0.000000             0.000000
# 25%              0.000000                  0.000000             0.870000
# 50%              0.000000                  0.020000             2.930000
# 75%              1.310000                  0.670000             4.460000
# max             21.920000                  6.400000            12.510000
#
#        SedentaryActiveDistance  VeryActiveMinutes  FairlyActiveMinutes  \
# count               457.000000         457.000000           457.000000
# mean                  0.001904          16.623632            13.070022
# std                   0.008487          28.919704            36.208635
# min                   0.000000           0.000000             0.000000
# 25%                   0.000000           0.000000             0.000000
# 50%                   0.000000           0.000000             1.000000
# 75%                   0.000000          25.000000            16.000000
# max                   0.100000         202.000000           660.000000
#
#        LightlyActiveMinutes  SedentaryMinutes     Calories    year  \
# count            457.000000        457.000000   457.000000   457.0
# mean             170.070022        995.282276  2189.452954  2016.0
# std              122.205372        337.021404   815.484523     0.0
# min                0.000000         32.000000     0.000000  2016.0
# 25%               64.000000        728.000000  1776.000000  2016.0
# 50%              181.000000       1057.000000  2062.000000  2016.0
# 75%              257.000000       1285.000000  2667.000000  2016.0
# max              720.000000       1440.000000  4562.000000  2016.0
#
#             month        date
# count  457.000000  457.000000
# mean     3.838074    9.214442
# std      0.368786    7.966072
# min      3.000000    1.000000
# 25%      4.000000    4.000000
# 50%      4.000000    7.000000
# 75%      4.000000   11.000000
# max      4.000000   31.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
# %matplotlib inline
plt.figure(figsize=(15,8))
ax = sns.boxplot(x='date', y='Calories', data=activity1)
ax.set_title('Box plot of Calories with Jitter bu day of the month')
plt.show()

# %%
plt.figure(figsize=(15,8))
ax = sns.barplot(x='date', y='Calories',data=activity1)
ax.set_title('Barplot of calories by the day of the week')
# Out:
# Text(0.5, 1.0, 'Barplot of calories by the day of the week')

# %%
activity1['Week'] = pd.to_datetime(activity1.ActivityDate).dt.week
activity1['Year'] = pd.to_datetime(activity1.ActivityDate).dt.year
# Out:
# C:\Users\ols\AppData\Local\Temp/ipykernel_576/2340274953.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   activity1['Week'] = pd.to_datetime(activity1.ActivityDate).dt.week

# %%
activity1.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  \
# 0  1503960366    3/25/2016       11004           7.11
# 1  1503960366    3/26/2016       17609          11.55
# 2  1503960366    3/27/2016       12736           8.53
# 3  1503960366    3/28/2016       13231           8.93
# 4  1503960366    3/29/2016       12041           7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
# 3                 4.95                      0.0                 39
# 4                 4.61                      0.0                 28
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                   12                   205               804      1819
# 1                   17                   274               588      2154
# 2                    5                   268               605      1944
# 3                   20                   224              1080      1932
# 4                   28                   243               763      1886
#
#    year  month  date  Week  Year
# 0  2016      3    25    12  2016
# 1  2016      3    26    12  2016
# 2  2016      3    27    12  2016
# 3  2016      3    28    13  2016
# 4  2016      3    29    13  2016

# %%
activity1['ActivityDate'] = pd.to_datetime(activity1['ActivityDate'])

# %%
activity1.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  \
# 0  1503960366   2016-03-25       11004           7.11
# 1  1503960366   2016-03-26       17609          11.55
# 2  1503960366   2016-03-27       12736           8.53
# 3  1503960366   2016-03-28       13231           8.93
# 4  1503960366   2016-03-29       12041           7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
# 3                 4.95                      0.0                 39
# 4                 4.61                      0.0                 28
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                   12                   205               804      1819
# 1                   17                   274               588      2154
# 2                    5                   268               605      1944
# 3                   20                   224              1080      1932
# 4                   28                   243               763      1886
#
#    year  month  date  Week  Year
# 0  2016      3    25    12  2016
# 1  2016      3    26    12  2016
# 2  2016      3    27    12  2016
# 3  2016      3    28    13  2016
# 4  2016      3    29    13  2016

# %%
activity1.ActivityDate.dtype
# Out:
# dtype('<M8[ns]')

# %%
activity1['ActivityDate'] = pd.to_datetime(activity1['ActivityDate'])

# %%
activity1['day'] = activity1['ActivityDate'].dt.weekday

# %%
activity1.head(10)
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  \
# 0  1503960366   2016-03-25       11004           7.11
# 1  1503960366   2016-03-26       17609          11.55
# 2  1503960366   2016-03-27       12736           8.53
# 3  1503960366   2016-03-28       13231           8.93
# 4  1503960366   2016-03-29       12041           7.85
# 5  1503960366   2016-03-30       10970           7.16
# 6  1503960366   2016-03-31       12256           7.86
# 7  1503960366   2016-04-01       12262           7.87
# 8  1503960366   2016-04-02       11248           7.25
# 9  1503960366   2016-04-03       10016           6.37
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
# 5                       0.0                2.36                      0.51
# 6                       0.0                2.29                      0.49
# 7                       0.0                3.32                      0.83
# 8                       0.0                3.00                      0.45
# 9                       0.0                0.91                      1.28
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
# 3                 4.95                      0.0                 39
# 4                 4.61                      0.0                 28
# 5                 4.29                      0.0                 30
# 6                 5.04                      0.0                 33
# 7                 3.64                      0.0                 47
# 8                 3.74                      0.0                 40
# 9                 4.18                      0.0                 15
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                   12                   205               804      1819
# 1                   17                   274               588      2154
# 2                    5                   268               605      1944
# 3                   20                   224              1080      1932
# 4                   28                   243               763      1886
# 5                   13                   223              1174      1820
# 6                   12                   239               820      1889
# 7                   21                   200               866      1868
# 8                   11                   244               636      1843
# 9                   30                   314               655      1850
#
#    year  month  date  Week  Year  day
# 0  2016      3    25    12  2016    4
# 1  2016      3    26    12  2016    5
# 2  2016      3    27    12  2016    6
# 3  2016      3    28    13  2016    0
# 4  2016      3    29    13  2016    1
# 5  2016      3    30    13  2016    2
# 6  2016      3    31    13  2016    3
# 7  2016      4     1    13  2016    4
# 8  2016      4     2    13  2016    5
# 9  2016      4     3    13  2016    6

# %%
plt.figure(figsize=(15,8))
ax = sns.barplot(x='day', y='Calories',  data=activity1)

ax.set_title('Barplot of calories by the day of the week')
# Out:
# Text(0.5, 1.0, 'Barplot of calories by the day of the week')

# %%
plt.figure(figsize=(15,8))
ax = sns.scatterplot(x='Calories', y='SedentaryMinutes', data=activity1)
ax.set_title('Scatterplot of calories and intense_activities')
# Out:
# Text(0.5, 1.0, 'Scatterplot of calories and intense_activities')

# %%
plt.figure(figsize=(15,8))

ax = sns.scatterplot(x='Calories', y='LightlyActiveMinutes', data=activity1)

ax.set_title('Scatterplot of calories and intense_activities')
# Out:
# Text(0.5, 1.0, 'Scatterplot of calories and intense_activities')

# %%
plt.figure(figsize=(15,8))
ax = sns.scatterplot(x='Calories', y='FairlyActiveMinutes', data=activity1)

ax.set_title('Scatterplot of calories vs Fairly Active Minutes')
# Out:
# Text(0.5, 1.0, 'Scatterplot of calories vs Fairly Active Minutes')

# %%
plt.figure(figsize=(15,8))

ax = sns.scatterplot(x='Calories', y='VeryActiveMinutes', data=activity1)

ax.set_title('Scatterplot of calories and intense_activities')
# Out:
# Text(0.5, 1.0, 'Scatterplot of calories and intense_activities')

# %%
activity1.head(10)
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  \
# 0  1503960366   2016-03-25       11004           7.11
# 1  1503960366   2016-03-26       17609          11.55
# 2  1503960366   2016-03-27       12736           8.53
# 3  1503960366   2016-03-28       13231           8.93
# 4  1503960366   2016-03-29       12041           7.85
# 5  1503960366   2016-03-30       10970           7.16
# 6  1503960366   2016-03-31       12256           7.86
# 7  1503960366   2016-04-01       12262           7.87
# 8  1503960366   2016-04-02       11248           7.25
# 9  1503960366   2016-04-03       10016           6.37
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
# 5                       0.0                2.36                      0.51
# 6                       0.0                2.29                      0.49
# 7                       0.0                3.32                      0.83
# 8                       0.0                3.00                      0.45
# 9                       0.0                0.91                      1.28
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
# 3                 4.95                      0.0                 39
# 4                 4.61                      0.0                 28
# 5                 4.29                      0.0                 30
# 6                 5.04                      0.0                 33
# 7                 3.64                      0.0                 47
# 8                 3.74                      0.0                 40
# 9                 4.18                      0.0                 15
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                   12                   205               804      1819
# 1                   17                   274               588      2154
# 2                    5                   268               605      1944
# 3                   20                   224              1080      1932
# 4                   28                   243               763      1886
# 5                   13                   223              1174      1820
# 6                   12                   239               820      1889
# 7                   21                   200               866      1868
# 8                   11                   244               636      1843
# 9                   30                   314               655      1850
#
#    year  month  date  Week  Year  day
# 0  2016      3    25    12  2016    4
# 1  2016      3    26    12  2016    5
# 2  2016      3    27    12  2016    6
# 3  2016      3    28    13  2016    0
# 4  2016      3    29    13  2016    1
# 5  2016      3    30    13  2016    2
# 6  2016      3    31    13  2016    3
# 7  2016      4     1    13  2016    4
# 8  2016      4     2    13  2016    5
# 9  2016      4     3    13  2016    6

# %%
activity1=activity1.drop(['Week','Year'],axis=1)

# %%
activity1.head(10)
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  \
# 0  1503960366   2016-03-25       11004           7.11
# 1  1503960366   2016-03-26       17609          11.55
# 2  1503960366   2016-03-27       12736           8.53
# 3  1503960366   2016-03-28       13231           8.93
# 4  1503960366   2016-03-29       12041           7.85
# 5  1503960366   2016-03-30       10970           7.16
# 6  1503960366   2016-03-31       12256           7.86
# 7  1503960366   2016-04-01       12262           7.87
# 8  1503960366   2016-04-02       11248           7.25
# 9  1503960366   2016-04-03       10016           6.37
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
# 5                       0.0                2.36                      0.51
# 6                       0.0                2.29                      0.49
# 7                       0.0                3.32                      0.83
# 8                       0.0                3.00                      0.45
# 9                       0.0                0.91                      1.28
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
# 3                 4.95                      0.0                 39
# 4                 4.61                      0.0                 28
# 5                 4.29                      0.0                 30
# 6                 5.04                      0.0                 33
# 7                 3.64                      0.0                 47
# 8                 3.74                      0.0                 40
# 9                 4.18                      0.0                 15
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                   12                   205               804      1819
# 1                   17                   274               588      2154
# 2                    5                   268               605      1944
# 3                   20                   224              1080      1932
# 4                   28                   243               763      1886
# 5                   13                   223              1174      1820
# 6                   12                   239               820      1889
# 7                   21                   200               866      1868
# 8                   11                   244               636      1843
# 9                   30                   314               655      1850
#
#    year  month  date  day
# 0  2016      3    25    4
# 1  2016      3    26    5
# 2  2016      3    27    6
# 3  2016      3    28    0
# 4  2016      3    29    1
# 5  2016      3    30    2
# 6  2016      3    31    3
# 7  2016      4     1    4
# 8  2016      4     2    5
# 9  2016      4     3    6

# %%
activity1.shape
# Out:
# (457, 18)

# %%
col_select = ['Calories','VeryActiveMinutes','FairlyActiveMinutes','LightlyActiveMinutes','SedentaryMinutes']
wide_df = activity1[col_select]

# figure size
plt.figure(figsize=(15,8))

# timeseries plot using lineplot
ax = sns.lineplot(data=wide_df)

ax.set_title('Un-normalized value of calories and different activities based on activity minutes')
# Out:
# Text(0.5, 1.0, 'Un-normalized value of calories and different activities based on activity minutes')

# %%
plt.figure(figsize=(15,8))

ax = sns.scatterplot(x='Calories', y='TotalDistance', data=activity1)

ax.set_title('Scatterplot of calories and intense_activities')
# Out:
# Text(0.5, 1.0, 'Scatterplot of calories and intense_activities')

# %%
plt.figure(figsize=(15,8))

# Simple scatterplot between calories burnt and the loggged activities distance
ax = sns.scatterplot(x='Calories', y='LoggedActivitiesDistance', data=activity1)

ax.set_title('Scatterplot of calories and intense_activities')
# Out:
# Text(0.5, 1.0, 'Scatterplot of calories and intense_activities')

# %%
# figure size
plt.figure(figsize=(15,8))

# Simple scatterplot between calories burnt and the distance of intense activies
ax = sns.scatterplot(x='Calories', y='VeryActiveDistance', data=activity1)

ax.set_title('Scatterplot of calories and intense_activities')
# Out:
# Text(0.5, 1.0, 'Scatterplot of calories and intense_activities')

# %%
plt.figure(figsize=(15,8))

ax = sns.scatterplot(x='Calories', y='ModeratelyActiveDistance', data=activity1)

ax.set_title('Scatterplot of calories and intense_activities')
# Out:
# Text(0.5, 1.0, 'Scatterplot of calories and intense_activities')

# %%
plt.figure(figsize=(15,8))

ax = sns.scatterplot(x='Calories', y='LightActiveDistance', data=activity1)

ax.set_title('Scatterplot of calories and intense_activities')
# Out:
# Text(0.5, 1.0, 'Scatterplot of calories and intense_activities')

# %%
rol_select = ['TotalDistance','LoggedActivitiesDistance','VeryActiveDistance','ModeratelyActiveDistance', 'LightActiveDistance']
wide_df1 = activity1[rol_select]

plt.figure(figsize=(15,8))

ax = sns.lineplot(data=wide_df1)

ax.set_title('Un-normalized value of calories and different activities based on distance')
# Out:
# Text(0.5, 1.0, 'Un-normalized value of calories and different activities based on distance')

# %% [markdown]
# #The EDA here gives us the insight about the relation between the active hours, the distance for which the user has moderate and intense activity and the calories burnt during that period.
